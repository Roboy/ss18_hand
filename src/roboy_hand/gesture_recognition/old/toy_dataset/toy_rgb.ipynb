# %%
import os
import sys
import glob
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.autograd import Variable

import numpy as np

from skimage import io, transform
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split

#Dataset
import torch.utils.data as utils

#Import PyTorch Models
path = os.path.join(os.path.dirname(os.path.abspath('__file__')), "models")
sys.path.append(path)
from models import *

#To deepcopy best model
import copy

#Get root path
root_path = os.path.join(os.path.dirname(os.path.abspath('__file__')), "Marcel-Train")
f_id = ["A", "B", "C", "Five", "Point", "V"]

#Find files inside the path
files = glob.glob(os.path.join(root_path, "A", "*.ppm"))

# %%
#Show a sample image
img = io.imread("C:/Users/Bilal/git/gesture_recog_toy/Marcel-Train/A/A-train0001.ppm")
io.imshow(img)
plt.show()
# Out:
# C:\Anaconda3\lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and

# %%
#Read train and validation dataset
dataset = []
labels = []

#Go inside each f_id directory
for i in range(len(f_id)):
    #Find image paths
    path = os.path.join(root_path, f_id[i])
    image_names = glob.glob(os.path.join(path, "*.ppm"))
    
    counter=0
    for img_path in image_names:
        
        #Read image from image path
        img = io.imread(img_path)

        #Resize each image to (64,64,3)
        img = transform.resize(img, (64, 64))
        #Transpose image to C, H, W
        img = img.transpose((2,0,1))
        
        #Add image to dataset
        dataset.append(img)
        
        #Add to labels
        labels.append(i)
# Out:
# C:\Anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "

# %%
#Read test data

#Get root path
root_path = os.path.join(os.path.dirname(os.path.abspath('__file__')), "Marcel-Test")
f_id = ["A", "B", "C", "Five", "Point", "V"]
type_id = ['complex', 'uniform']

test_dataset = []
test_labels = []

#Go inside each f_id directory and type_id directory
for i in range(len(f_id)):
    for j in range(len(type_id)):
        #Find image paths
        path = os.path.join(root_path, f_id[i], type_id[j])
        image_names = glob.glob(os.path.join(path, "*.ppm"))
        
        for img_path in image_names:
            #Read image from image path
            img = io.imread(img_path)

            #Resize each image to (64,64,3)
            img = transform.resize(img, (64, 64))

            #Transpose image to C, H, W
            img = img.transpose((2,0,1))

            #Add image to dataset
            test_dataset.append(img)

            #Add to labels
            test_labels.append(i)
# Out:
# C:\Anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "

# %%
dataset = np.array(dataset).astype(float)
labels = np.array(labels).astype(float)

test_dataset = np.array(test_dataset).astype(float)
test_labels = np.array(test_labels).astype(float)

#Split dataset into train, validation and test sets
X_val, X_train, y_val, y_train = train_test_split(dataset, labels, test_size=0.8)
X_test, y_test = test_dataset, test_labels

#Calculate mean and std of train set
mean = np.mean(X_train)
std = np.std(X_train)
print("Train set mean:", mean, " std:", std)
# Out:
# Train set mean: 0.4869802166713131  std: 0.22140219973682285

# %%
#Normalize datasets
X_train_normalized = (X_train - mean) / std
X_val_normalized = (X_val - mean) / std
X_test_normalized = (X_test - mean) / std

# %%
#Convert to torch
X_train_torch = torch.from_numpy(X_train_normalized).float()
X_val_torch = torch.from_numpy(X_val_normalized).float()
X_test_torch = torch.from_numpy(X_test_normalized).float()

y_train_torch = torch.from_numpy(y_train).float()
y_val_torch = torch.from_numpy(y_val).float()
y_test_torch = torch.from_numpy(y_test).float()

# %%
#Get torch data loaders
train_dataset = utils.TensorDataset(X_train_torch, y_train_torch) # create your dataset
train_loader = utils.DataLoader(train_dataset, batch_size=10, shuffle=True, num_workers=4) # create your dataloader

val_dataset = utils.TensorDataset(X_val_torch, y_val_torch) # create your dataset
val_loader = utils.DataLoader(val_dataset, batch_size=10, shuffle=True, num_workers=4) # create your dataloader

test_dataset = utils.TensorDataset(X_test_torch, y_test_torch) # create your dataset
test_loader = utils.DataLoader(test_dataset, batch_size=10, shuffle=True, num_workers=4) # create your dataloader

# %%
#Create NN model
model = VGG('VGG16')

#Target has to be LongSensor for CrossEntropyLoss
criterion = nn.CrossEntropyLoss()

optimizer = torch.optim.Adam(model.parameters(), lr=1e-6, betas=(0.9, 0.999), eps=1e-8, weight_decay=5e-4)

# %%
#Initialize parameters
train_loss_history = []
train_acc_history = []
val_loss_history = []
val_acc_history = []

num_epochs = 100
iter_per_epoch = len(train_loader)

best_loss = np.inf

if torch.cuda.is_available():
    model.cuda()
    
for epoch in range(num_epochs):
    
    #TRAIN
    model.train()
    running_loss = 0.0
    train_acc = 0.0
    
    for i, (inputs, targets) in enumerate(train_loader):
        inputs, targets = Variable(inputs), Variable(targets)
        
        if torch.cuda.is_available():
            inputs, targets = inputs.cuda(), targets.cuda().long()
            
        # zero the parameter gradients
        optimizer.zero_grad()

        # forward + backward + optimize
        outputs = model(inputs)
        loss = criterion(outputs, targets)
        loss.backward()
        optimizer.step()
        
        # print statistics
        running_loss += loss.item()
        
        _, preds = torch.max(outputs, 1)

        train_acc += np.mean((preds == targets).data.cpu().numpy())
        
    train_acc /= i + 1
    running_loss /= i + 1
    train_acc_history.append(train_acc)
    train_loss_history.append(running_loss)
    
    print('[%d] Train loss: %.3f,  Train acc: %.3f' %
          (epoch + 1, running_loss,  train_acc))
    
    #VALIDATION
    model.eval()
    val_running_loss = 0.0
    val_acc = 0.0
    
    for j, (val_inputs, val_targets) in enumerate(val_loader):
        val_inputs, val_targets = Variable(val_inputs), Variable(val_targets)
        
        if torch.cuda.is_available():
            val_inputs, val_targets = val_inputs.cuda(), val_targets.cuda().long()

        # forward
        val_outputs = model(val_inputs)
        val_loss = criterion(val_outputs, val_targets)
        
        # print statistics
        val_running_loss += val_loss.item()
        
        _, val_preds = torch.max(val_outputs, 1)

        val_acc += np.mean((val_preds == val_targets).data.cpu().numpy())
        
    val_acc /= j + 1
    val_running_loss /= j + 1
    val_acc_history.append(val_acc)
    val_loss_history.append(val_running_loss)
        
    print('[%d] Validation loss: %.3f,  Validation acc: %.3f' %
          (epoch + 1, val_running_loss,  val_acc))
    
    if val_running_loss < best_loss:
        best_loss = val_running_loss
        best_model = copy.deepcopy(model)
# Out:
# [1] Train loss: 1.556,  Train acc: 0.399
# [1] Validation loss: 1.407,  Validation acc: 0.480
# [2] Train loss: 1.290,  Train acc: 0.537
# [2] Validation loss: 1.208,  Validation acc: 0.583
# [3] Train loss: 1.092,  Train acc: 0.640
# [3] Validation loss: 1.047,  Validation acc: 0.666
# [4] Train loss: 0.939,  Train acc: 0.717
# [4] Validation loss: 0.917,  Validation acc: 0.719
# [5] Train loss: 0.804,  Train acc: 0.799
# [5] Validation loss: 0.810,  Validation acc: 0.770
# [6] Train loss: 0.682,  Train acc: 0.842
# [6] Validation loss: 0.716,  Validation acc: 0.806
# [7] Train loss: 0.577,  Train acc: 0.884
# [7] Validation loss: 0.607,  Validation acc: 0.832
# [8] Train loss: 0.479,  Train acc: 0.915
# [8] Validation loss: 0.522,  Validation acc: 0.871
# [9] Train loss: 0.398,  Train acc: 0.934
# [9] Validation loss: 0.468,  Validation acc: 0.886
# [10] Train loss: 0.337,  Train acc: 0.947
# [10] Validation loss: 0.401,  Validation acc: 0.913
# [11] Train loss: 0.270,  Train acc: 0.962
# [11] Validation loss: 0.338,  Validation acc: 0.936
# [12] Train loss: 0.227,  Train acc: 0.966
# [12] Validation loss: 0.300,  Validation acc: 0.937
# [13] Train loss: 0.185,  Train acc: 0.980
# [13] Validation loss: 0.278,  Validation acc: 0.939
# [14] Train loss: 0.154,  Train acc: 0.984
# [14] Validation loss: 0.237,  Validation acc: 0.954
# [15] Train loss: 0.130,  Train acc: 0.988
# [15] Validation loss: 0.218,  Validation acc: 0.953
# [16] Train loss: 0.105,  Train acc: 0.990
# [16] Validation loss: 0.193,  Validation acc: 0.961
# [17] Train loss: 0.090,  Train acc: 0.994
# [17] Validation loss: 0.176,  Validation acc: 0.959
# [18] Train loss: 0.073,  Train acc: 0.996
# [18] Validation loss: 0.171,  Validation acc: 0.962
# [19] Train loss: 0.060,  Train acc: 0.997
# [19] Validation loss: 0.164,  Validation acc: 0.963
# [20] Train loss: 0.049,  Train acc: 0.998
# [20] Validation loss: 0.142,  Validation acc: 0.962
# [21] Train loss: 0.043,  Train acc: 0.997
# [21] Validation loss: 0.149,  Validation acc: 0.962
# [22] Train loss: 0.036,  Train acc: 0.999
# [22] Validation loss: 0.136,  Validation acc: 0.959
# [23] Train loss: 0.029,  Train acc: 0.999
# [23] Validation loss: 0.130,  Validation acc: 0.961
# [24] Train loss: 0.024,  Train acc: 1.000
# [24] Validation loss: 0.120,  Validation acc: 0.965
# [25] Train loss: 0.021,  Train acc: 0.999
# [25] Validation loss: 0.122,  Validation acc: 0.963
# [26] Train loss: 0.018,  Train acc: 0.999
# [26] Validation loss: 0.119,  Validation acc: 0.967
# [27] Train loss: 0.016,  Train acc: 1.000
# [27] Validation loss: 0.108,  Validation acc: 0.968
# [28] Train loss: 0.013,  Train acc: 1.000
# [28] Validation loss: 0.101,  Validation acc: 0.969
# [29] Train loss: 0.011,  Train acc: 1.000
# [29] Validation loss: 0.108,  Validation acc: 0.964
# [30] Train loss: 0.010,  Train acc: 1.000
# [30] Validation loss: 0.106,  Validation acc: 0.967
# [31] Train loss: 0.008,  Train acc: 1.000
# [31] Validation loss: 0.116,  Validation acc: 0.961
# [32] Train loss: 0.007,  Train acc: 1.000
# [32] Validation loss: 0.104,  Validation acc: 0.968
# [33] Train loss: 0.006,  Train acc: 1.000
# [33] Validation loss: 0.105,  Validation acc: 0.969
# [34] Train loss: 0.005,  Train acc: 1.000
# [34] Validation loss: 0.101,  Validation acc: 0.965
# [35] Train loss: 0.004,  Train acc: 1.000
# [35] Validation loss: 0.101,  Validation acc: 0.966
# [36] Train loss: 0.004,  Train acc: 1.000
# [36] Validation loss: 0.114,  Validation acc: 0.964
# [37] Train loss: 0.003,  Train acc: 1.000
# [37] Validation loss: 0.102,  Validation acc: 0.960
# [38] Train loss: 0.003,  Train acc: 1.000
# [38] Validation loss: 0.101,  Validation acc: 0.970
# [39] Train loss: 0.003,  Train acc: 1.000
# [39] Validation loss: 0.105,  Validation acc: 0.966
# [40] Train loss: 0.002,  Train acc: 1.000
# [40] Validation loss: 0.099,  Validation acc: 0.969
# [41] Train loss: 0.003,  Train acc: 1.000
# [41] Validation loss: 0.097,  Validation acc: 0.969
# [42] Train loss: 0.002,  Train acc: 1.000
# [42] Validation loss: 0.103,  Validation acc: 0.968
# [43] Train loss: 0.002,  Train acc: 1.000
# [43] Validation loss: 0.105,  Validation acc: 0.962
# [44] Train loss: 0.001,  Train acc: 1.000
# [44] Validation loss: 0.105,  Validation acc: 0.964
# [45] Train loss: 0.002,  Train acc: 1.000
# [45] Validation loss: 0.095,  Validation acc: 0.967
# [46] Train loss: 0.001,  Train acc: 1.000
# [46] Validation loss: 0.097,  Validation acc: 0.968
# [47] Train loss: 0.001,  Train acc: 1.000
# [47] Validation loss: 0.113,  Validation acc: 0.969
# [48] Train loss: 0.001,  Train acc: 1.000
# [48] Validation loss: 0.100,  Validation acc: 0.967
# [49] Train loss: 0.002,  Train acc: 1.000
# [49] Validation loss: 0.100,  Validation acc: 0.969
# [50] Train loss: 0.001,  Train acc: 1.000
# [50] Validation loss: 0.092,  Validation acc: 0.971
# [51] Train loss: 0.001,  Train acc: 1.000
# [51] Validation loss: 0.102,  Validation acc: 0.966
# [52] Train loss: 0.001,  Train acc: 1.000
# [52] Validation loss: 0.103,  Validation acc: 0.970
# [53] Train loss: 0.001,  Train acc: 1.000
# [53] Validation loss: 0.099,  Validation acc: 0.971
# [54] Train loss: 0.001,  Train acc: 1.000
# [54] Validation loss: 0.101,  Validation acc: 0.968
# [55] Train loss: 0.001,  Train acc: 1.000
# [55] Validation loss: 0.111,  Validation acc: 0.966
# [56] Train loss: 0.001,  Train acc: 1.000
# [56] Validation loss: 0.108,  Validation acc: 0.966
# [57] Train loss: 0.000,  Train acc: 1.000
# [57] Validation loss: 0.099,  Validation acc: 0.970
# [58] Train loss: 0.000,  Train acc: 1.000
# [58] Validation loss: 0.094,  Validation acc: 0.966
# [59] Train loss: 0.000,  Train acc: 1.000
# [59] Validation loss: 0.113,  Validation acc: 0.964
# [60] Train loss: 0.000,  Train acc: 1.000
# [60] Validation loss: 0.115,  Validation acc: 0.969
# [61] Train loss: 0.000,  Train acc: 1.000
# [61] Validation loss: 0.120,  Validation acc: 0.965
# [62] Train loss: 0.000,  Train acc: 1.000
# [62] Validation loss: 0.112,  Validation acc: 0.967
# [63] Train loss: 0.000,  Train acc: 1.000
# [63] Validation loss: 0.110,  Validation acc: 0.970
# [64] Train loss: 0.000,  Train acc: 1.000
# [64] Validation loss: 0.102,  Validation acc: 0.969
# [65] Train loss: 0.000,  Train acc: 1.000
# [65] Validation loss: 0.108,  Validation acc: 0.972
# [66] Train loss: 0.000,  Train acc: 1.000
# [66] Validation loss: 0.111,  Validation acc: 0.965
# [67] Train loss: 0.000,  Train acc: 1.000
# [67] Validation loss: 0.108,  Validation acc: 0.972
# [68] Train loss: 0.000,  Train acc: 1.000
# [68] Validation loss: 0.098,  Validation acc: 0.973
# [69] Train loss: 0.000,  Train acc: 1.000
# [69] Validation loss: 0.097,  Validation acc: 0.969
# [70] Train loss: 0.000,  Train acc: 1.000
# [70] Validation loss: 0.115,  Validation acc: 0.966
# [71] Train loss: 0.000,  Train acc: 1.000
# [71] Validation loss: 0.110,  Validation acc: 0.969
# [72] Train loss: 0.000,  Train acc: 1.000
# [72] Validation loss: 0.117,  Validation acc: 0.966
# [73] Train loss: 0.000,  Train acc: 1.000
# [73] Validation loss: 0.117,  Validation acc: 0.973
# [74] Train loss: 0.000,  Train acc: 1.000
# [74] Validation loss: 0.111,  Validation acc: 0.972
# [75] Train loss: 0.000,  Train acc: 1.000
# [75] Validation loss: 0.103,  Validation acc: 0.970
# [76] Train loss: 0.000,  Train acc: 1.000
# [76] Validation loss: 0.103,  Validation acc: 0.970
# [77] Train loss: 0.000,  Train acc: 1.000
# [77] Validation loss: 0.107,  Validation acc: 0.971
# [78] Train loss: 0.000,  Train acc: 1.000
# [78] Validation loss: 0.103,  Validation acc: 0.977
# [79] Train loss: 0.000,  Train acc: 1.000
# [79] Validation loss: 0.113,  Validation acc: 0.973
# [80] Train loss: 0.000,  Train acc: 1.000
# [80] Validation loss: 0.116,  Validation acc: 0.969
# [81] Train loss: 0.000,  Train acc: 1.000
# [81] Validation loss: 0.112,  Validation acc: 0.969
# [82] Train loss: 0.000,  Train acc: 1.000
# [82] Validation loss: 0.101,  Validation acc: 0.971
# [83] Train loss: 0.000,  Train acc: 1.000
# [83] Validation loss: 0.115,  Validation acc: 0.972
# [84] Train loss: 0.000,  Train acc: 1.000
# [84] Validation loss: 0.120,  Validation acc: 0.970
# [85] Train loss: 0.000,  Train acc: 1.000
# [85] Validation loss: 0.122,  Validation acc: 0.967
# [86] Train loss: 0.001,  Train acc: 1.000
# [86] Validation loss: 0.111,  Validation acc: 0.974
# [87] Train loss: 0.000,  Train acc: 1.000
# [87] Validation loss: 0.113,  Validation acc: 0.972
# [88] Train loss: 0.000,  Train acc: 1.000
# [88] Validation loss: 0.112,  Validation acc: 0.969
# [89] Train loss: 0.000,  Train acc: 1.000
# [89] Validation loss: 0.102,  Validation acc: 0.974
# [90] Train loss: 0.000,  Train acc: 1.000
# [90] Validation loss: 0.109,  Validation acc: 0.970
# [91] Train loss: 0.000,  Train acc: 1.000
# [91] Validation loss: 0.120,  Validation acc: 0.969
# [92] Train loss: 0.001,  Train acc: 1.000
# [92] Validation loss: 0.108,  Validation acc: 0.973
# [93] Train loss: 0.000,  Train acc: 1.000
# [93] Validation loss: 0.115,  Validation acc: 0.970
# [94] Train loss: 0.000,  Train acc: 1.000
# [94] Validation loss: 0.110,  Validation acc: 0.971
# [95] Train loss: 0.000,  Train acc: 1.000
# [95] Validation loss: 0.107,  Validation acc: 0.973
# [96] Train loss: 0.000,  Train acc: 1.000
# [96] Validation loss: 0.098,  Validation acc: 0.970
# [97] Train loss: 0.000,  Train acc: 1.000
# [97] Validation loss: 0.108,  Validation acc: 0.968
# [98] Train loss: 0.000,  Train acc: 1.000
# [98] Validation loss: 0.117,  Validation acc: 0.969
# [99] Train loss: 0.000,  Train acc: 1.000
# [99] Validation loss: 0.120,  Validation acc: 0.971
# [100] Train loss: 0.000,  Train acc: 1.000
# [100] Validation loss: 0.118,  Validation acc: 0.968

# %%
#Timestamp
import datetime

#Save model
currentDT = datetime.datetime.now().strftime('%Y-%m-%d_%H-%M-%S')
path = os.path.join(os.path.dirname(os.path.abspath('__file__')), "saved_models", "vgg_rgb_" + str(num_epochs) + "_" + currentDT + ".model")
torch.save(best_model.state_dict(), path)

# %%
plt.plot(train_loss_history, '-o')
plt.plot(val_loss_history, '-o')
plt.xlabel('iteration')
plt.ylabel('loss')
plt.show()

plt.plot(train_acc_history, '-o')
plt.plot(val_acc_history, '-o')
plt.legend(['train', 'val'], loc='upper left')
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.show()

# %%
#TEST
model.eval()
test_acc = 0.0
test_running_loss = 0.0
    
for i, (test_inputs, test_targets) in enumerate(test_loader):
    test_inputs, test_targets = Variable(test_inputs), Variable(test_targets)

    if torch.cuda.is_available():
        test_inputs, test_targets = test_inputs.cuda(), test_targets.cuda().long()

    # forward
    test_outputs = best_model(test_inputs)
    test_loss = criterion(test_outputs, test_targets)

    # print statistics
    test_running_loss += test_loss.item()

    _, test_preds = torch.max(test_outputs, 1)

    test_acc += np.mean((test_preds == test_targets).data.cpu().numpy())

test_acc /= i + 1
test_running_loss /= i + 1

print('Test loss: %.3f,  Test acc: %.3f' %
          (test_running_loss,  test_acc))
# Out:
# Test loss: 1.665,  Test acc: 0.508
